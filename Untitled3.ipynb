# %% [markdown]
# <a href="https://colab.research.google.com/github/caio86-86/atividades-de-PA-2026/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
comprimento = 2
largura = 4
area = comprimento * largura

print(f"total da area {area}")
# Out:
# total da area 8

# %%
# entrada
