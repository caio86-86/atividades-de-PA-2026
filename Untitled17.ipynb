# %% [markdown]
# <a href="https://colab.research.google.com/github/caio86-86/atividades-de-PA-2026/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# iterações e laços de repetição

print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
# Out:
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!

# %%
for i in range (5):
  print ("Olá mundo!")
# Out:
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!
# Olá mundo!

# %%
for i in range (5):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (1,6):
  print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Escrever um programa que inprime de 5 até 0

for i in range (7):
  print (6 - i)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
# Escrever um programa que inprime os números pares de 0 a 10

for i in range(0, 11, 2):
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
for i in range (0, 11, 2):
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
 # imrpimir números impares
for i in range (1, 11, 2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
# escrever um programa que o usuário digita um número de 1 a 10 e imprime a tabuada

# entrada

numero = int(input("digite um número de 1 a 10"))

# processamneto

for i in range (1, 11):
  print(numero * i)
