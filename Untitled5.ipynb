# %% [markdown]
# <a href="https://colab.research.google.com/github/caio86-86/atividades-de-PA-2026/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int (input("digite um número:"))

b = int (input("digite um número"))

if a > b

print (f"{a}maior que {b}>")

else:

  print (f"{b}maior que {a}")

  digite um número : 3
  digite um número : 9
  9 é maior que 3
# Out:
#   File "/tmp/ipykernel_318/2806212303.py", line 5
#     if a > b
#             ^
# SyntaxError: expected ':'

# %%
# escrever um programa que verifica se o usuário é maior de idade

nome = str (input('digite seu nome:'))
idade = int (input("digite sua idade:"))

if idade > 18:

  print (f"{nome},voce é maior de idade")

  else :

    print (f"{nome},voce é menor de idade")

    digite seu nome : Márcio
    digite sua idade : 52
    Márcio, você é maior de idade

# %%
# escrever um programa que verifica se o número é impar ou par

número = int (input("digite um número:"))

if o número % 2 == 0:

  print(f"O número" {número} é par.)

  else :

    print(f"O número" {número} é ímpar.)

    Digite um número : 4

    4 é um número par
# Out:
#   File "/tmp/ipykernel_318/909540366.py", line 5
#     if o número % 2 == 0:
#          ^
# SyntaxError: invalid syntax

# %%
# escrever um programa que verifica uma senha simples, senha==1234, saida acesso permitido

senha = 1234

senha_digitada = int ( input ("digite sua senha "))

if senha == senha_digitada:

  print ("acesso permitido")

  else :

    print ("senha incorreta,digite novamente!")

    senha_digitada = int (input ( "digite sua senha"))

    if senha == senha_digitada:

      print ("acesso permitido")

      else :

        print ("senha incorreta,tente mais tarde!3")

# %%
# escrever um programa que verifica se um número é maior que 10 :

número = int(input("digite um número"))

if número > 10:

  print(f"{numero }maior que 10.")

  else :

    print(f"{numero}menor que 10.")]

    digite um número : 12

    12 é maior que 10

# %%
# escreva um programa que :
# peça o valor da compra
# se o valor for mairo que 100, aplique um desconto de 10%
# se não mostre o valor normal

compra = float (input("digite o valor da compra:"))

if compra > 100 :

  desconto = compra * 0.9

print (desconto)

else:

print (compra)

digite o valor da compra : 12

# %%
# escrever um programa que o aluno digita 04 notas do bimestre e o programa calcula a média e mostra na saída se o aluno foi aprovado, recuperação ou reprovado

# nota 1= float(input("digite a nota do 1 bimestre"))
# nota 2= float(input("digite a nota do 2 bimestre"))
# nota 3= float(input("diogite a nota do 3 bimestre"))
# nota 4+ fçloat(input("digite a nota do 4 bimestre"))

media = (nota 1 + nota 2 + nota 3 + nota 4)/4

if media >= 7

print (f"voce foi aprovado, sua média foi : {média}")

elif media >=5:

  print (f"voce esta de recuperacao")

  else :

    print (f"voce foi reprovado:{media}")

# %%
# escrever um programa que faz as 04 operações aritmética. (Calculadora simples)

print ("|-----------CALCULADORA SIMPLES-----------|")
print ("|                                         |")
print ("|-----------------MENU--------------------|")
print ("|                                         |")
print ("|Soma = 1                                 |")
print ("|                                         |")
print ("|Subtração = 2                            |")
print ("|                                         |")
print ("|Multiplicação = 3                        |")
print ("|                                         |")
print ("|Divisão = 4                              |")
print ("|                                         |")

# entrada
num1 = float(input("Digite o primeiro número:"))
opcao = int(input("Digite a opção desejada (1-4):"))
num2 = float(input("Digite o segundo número:"))

# Processamento e saida

if opcao == 1:
  resultado = num1 + num2
  print(f"O resultado da soma é: {resultado}")
elif opcao == 2:
  resultado = num1 - num2
  print(f"O resultado da subtração é: {resultado}")
elif opcao == 3:
  resultado = num1 * num2
  print(f"O resultado da multiplicação é: {resultado}")
elif opcao == 4:
  if num2 != 0:
    resultado = num1 / num2
    print(f"O resultado da divisão é: {resultado}")
  else:
    print("Erro: Divisão por zero não é permitida.")
else:
  print("Opção inválida. Por favor, escolha um número entre 1 e 4.")
# Out:
# |-----------CALCULADORA SIMPLES-----------|
# |                                         |
# |-----------------MENU--------------------|
# |                                         |
# |Soma = 1                                 |
# |                                         |
# |Subtração = 2                            |
# |                                         |
# |Multiplicação = 3                        |
# |                                         |
# |Divisão = 4                              |
# |                                         |

# %%
# escrever um programa que classifica os triangulos

# Verificar se formam um triangulo válido

# Tipo :

# equilátero
# Isósceles
# escaleno

# entrada: Solicitar os comprimentos dos três lados do triângulo
lado1 = float(input("Digite o comprimento do primeiro lado: "))
lado2 = float(input("Digite o comprimento do segundo lado: "))
lado3 = float(input("Digite o comprimento do terceiro lado: "))

# processamento e saida

# Verificar se os lados formam um triângulo válido (desigualdade triangular)
if (lado1 + lado2 > lado3) and (lado1 + lado3 > lado2) and (lado2 + lado3 > lado1):
    print("Os lados informados podem formar um triângulo.")

    # Classificar o triângulo
    if lado1 == lado2 == lado3:
        print("O triângulo é Equilátero (3 lados iguais).")
    elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
        print("O triângulo é Isósceles (2 lados iguais).")
    else:
        print("O triângulo é Escaleno (0 lados iguais).")
else:
    print("Os lados informados NÃO podem formar um triângulo válido.")
# Out:
# Digite o comprimento do primeiro lado: 2
# Digite o comprimento do segundo lado: 3
# Digite o comprimento do terceiro lado: 4
# Os lados informados podem formar um triângulo.
# O triângulo é Escaleno (0 lados iguais).
